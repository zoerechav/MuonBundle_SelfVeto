# %%
import numpy as np
import math
import tables
import h5py
import tables
import glob
import h5py
import pandas as pd
import yaml
import matplotlib.pyplot as plt
from matplotlib import colors as clrs
import matplotlib as mpl
import simweights
# %matplotlib inline

import I3Tray
from icecube.icetray import I3Units
from icecube import icetray, dataio, dataclasses
from icecube.simprod import segments
import numpy as np

import collections
from icecube.hdfwriter import I3HDFTableService, I3HDFWriter

from icecube.dataclasses import I3Double, I3Particle, I3Direction, I3Position, I3VectorI3Particle, I3Constants, I3VectorOMKey


E_nu_bins = np.concatenate((np.logspace(1,2,1),np.logspace(2,6,8+1)))
E_nu_bin_centers = np.sqrt(E_nu_bins[:-1] * E_nu_bins[1:])
E_mu_bins = ((np.logspace(1,6,8+1)))
E_mu_bin_centers = np.sqrt(E_mu_bins[:-1] * E_mu_bins[1:])

nu_ticks = np.logspace(1,6,6)

# %%
I3_file_path = '/data/user/zrechav/simulation_scripts/22042/step_0_inject_veto_muons/00000-00999/Level0.0_nugen_IC86.2012_pass2.022042.000000.i3.bz2'
I3_file = dataio.I3File(I3_file_path)
frame = I3_file.pop_daq()
sorted(frame.keys())
# Out:
# ['BiasedSimulationWeight',
#  'CombinedMuonVetoI3MCTree',
#  'I3MCTree',
#  'I3MCTreeVetoMuon',
#  'I3MCTreeVetoMuon_preMuonProp',
#  'I3MCTreeVetoMuon_preMuonProp_RNGState',
#  'I3MCWeightDict',
#  'MCVetoMuonInjectionInfo',
#  'MMCTrackList',
#  'MMCTrackListVetoMuon',
#  'OldEventID',
#  'OldRunNumber']

# %%
multiplicity = []
old_run_num = []
muon_one_energy = []
muon_two_energy = []
muon_three_energy = []
muon_four_energy = []
number_muons_injected = []
weight = []

I3_file_path = '/data/user/zrechav/simulation_scripts/22042/step_0_inject_veto_muons/00000-00999/Level0.0_nugen_IC86.2012_pass2.022042.000000.i3.bz2'
I3_file = dataio.I3File(I3_file_path)
for i in range((2000)):
    #print(i)
    frame = I3_file.pop_daq()
    oldrunnumber = frame['OldEventID'].value
#     coszen= np.cos(37.1776)
#     depth = 1948 - (-221.33)
#     p_energy = 6983
#     reco_energy = 2410
#    flavour = 'NuMu'
    if oldrunnumber == 7469.0:
        counter = 0
        old_run_num.append(oldrunnumber)

        muoninfo = frame['MCVetoMuonInjectionInfo']
        muon_1_energy = muoninfo['muon_1_energy']
        muon_one_energy.append(muon_1_energy)
        if muon_1_energy != 0:
            counter +=1

        muon_2_energy = muoninfo['muon_2_energy']
        muon_two_energy.append(muon_2_energy)
        if muon_2_energy != 0:
                    counter +=1
        muon_3_energy = muoninfo['muon_3_energy']
        muon_three_energy.append(muon_3_energy)
        if muon_3_energy != 0:
            counter +=1

        muon_4_energy = muoninfo['muon_4_energy']
        muon_four_energy.append(muon_4_energy)
        if muon_4_energy != 0:
            counter +=1
        Multi = muoninfo['MultiplicitySample']
        multiplicity.append(Multi)

        Weight = frame['I3MCWeightDict']['TotalWeight']
        weight.append(Weight)
        
        number_muons_injected.append(counter)

# %%
import matplotlib.pyplot as plt
from collections import Counter

value_counts = Counter(number_muons_injected)

# Extract values and counts
values = list(value_counts.keys())
counts = list(value_counts.values())

f, ax = plt.subplots(1,1,figsize=(5,5), dpi = 300)
plt.bar(values, counts, tick_label=values)

plt.xlabel('Muon Multiplicity')
plt.ylabel('Count')
plt.title('')

plt.show()

# %%
Mask = [energy < 10.0 for energy in muon_two_energy]
gridpts = E_mu_bins

muon_one_energy = np.array(muon_one_energy)
muon_two_energy = np.array(muon_two_energy)
muon_three_energy = np.array(muon_three_energy)
muon_four_energy = np.array(muon_four_energy)
print(len(muon_one_energy))

muon_energy,_ = np.histogram(muon_one_energy[Mask],bins = gridpts)

muon_one,_ = np.histogram(muon_one_energy,bins = gridpts)
muon_two,_ = np.histogram(muon_two_energy,bins = gridpts)
muon_three,_ = np.histogram(muon_three_energy,bins = gridpts)
muon_four,_ = np.histogram(muon_four_energy,bins = gridpts)

muon_sum = muon_one + muon_two + muon_three + muon_four
# Out:
# 1000

# %%
import numpy as np
import matplotlib.pyplot as plt


bin_centers = np.sqrt(gridpts[:-1] * gridpts[1:])

fig, ax1 = plt.subplots(dpi=300)

#line1, = ax1.step(gridpts, axis_pieces[7], label='2410 GeV table estimate', color='blue')

muon_energy_normalized = muon_energy / np.sum(muon_energy)
#line2, = ax1.step(bin_centers, muon_energy, where='mid', label='Post-Injection: One Leading Muon', linestyle='dotted', color='red')
line2, = ax1.step(bin_centers, muon_sum, where='mid', label='Total Energy')
line2, = ax1.step(bin_centers, muon_one, where='mid', label='1st',linestyle='dashdot')
line2, = ax1.step(bin_centers, muon_two, where='mid', label='2nd',linestyle='dashdot')
line2, = ax1.step(bin_centers, muon_three, where='mid', label='3rd',linestyle='dashdot')
line2, = ax1.step(bin_centers, muon_four, where='mid', label='4th',linestyle='dashdot')
# Calculate error band for post-injected, simple std deviation
errors_line2 = np.sqrt(muon_energy) / np.sum(muon_energy)
#ax1.errorbar(bin_centers, muon_energy_normalized, yerr=errors_line2,fmt='none', ecolor='red', capsize=6, capthick=1, elinewidth=1, alpha=0.5)

#lines = [line2]
#labels = [line.get_label() for line in lines]
#ax1.legend(lines, labels, loc='upper right', fontsize=8)

# Set the x-axis to log scale
ax1.set_xscale('log')

# Set labels for the axes
ax1.legend()
ax1.set_xlabel('Muon Energy [GeV]')
ax1.set_ylabel('Counts', color='black')
plt.xticks(nu_ticks)
#ax1.set_ylim(0, 0.3)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have defined gridpts, axis_pieces, muon_energy, and other variables

bin_centers = np.sqrt(gridpts[:-1] * gridpts[1:])

# Add an extra bin edge on the left
bin_edges = np.concatenate(([gridpts[0]], bin_centers))

fig, ax1 = plt.subplots(figsize = (5,5),dpi=300)

muon_energy_normalized = muon_energy / np.sum(muon_energy)

# Plot step lines using the adjusted bin_edges
line2, = ax1.step(bin_edges, [muon_energy[0]] + list(muon_energy), where='mid', label='Total Energy')
line2, = ax1.step(bin_edges, [muon_one[0]] + list(muon_one), where='mid', label='1st', linestyle='dashdot')
line2, = ax1.step(bin_edges, [muon_two[0]] + list(muon_two), where='mid', label='2nd', linestyle='dashdot')
line2, = ax1.step(bin_edges, [muon_three[0]] + list(muon_three), where='mid', label='3rd', linestyle='dashdot')
line2, = ax1.step(bin_edges, [muon_four[0]] + list(muon_four), where='mid', label='4th', linestyle='dashdot')

# Set the x-axis to log scale
ax1.set_xscale('log')

# Set labels for the axes
ax1.legend()
ax1.set_xlabel('Muon Energy [GeV]')
ax1.set_ylabel('Counts', color='black')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


bin_centers = np.sqrt(gridpts[:-1] * gridpts[1:])

fig, ax1 = plt.subplots(dpi=300)

#line1, = ax1.step(gridpts, axis_pieces[7], label='2410 GeV table estimate', color='blue')

muon_energy_normalized = muon_energy / np.sum(muon_energy)
#line2, = ax1.step(bin_centers, muon_energy, where='mid', label='Post-Injection: One Leading Muon', linestyle='dotted', color='red')
line2, = ax1.plot(bin_centers, muon_sum, label='Total Energy', linestyle='dotted')
line2, = ax1.plot(bin_centers, muon_one, label='1st')
line2, = ax1.plot(bin_centers, muon_two, label='2nd')
line2, = ax1.plot(bin_centers, muon_three, label='3rd')
line2, = ax1.plot(bin_centers, muon_four, label='4th')

# Calculate error band for post-injected, simple std deviation
errors_line2 = np.sqrt(muon_energy) / np.sum(muon_energy)
#ax1.errorbar(bin_centers, muon_energy_normalized, yerr=errors_line2,fmt='none', ecolor='red', capsize=6, capthick=1, elinewidth=1, alpha=0.5)

#lines = [line2]
#labels = [line.get_label() for line in lines]
#ax1.legend(lines, labels, loc='upper right', fontsize=8)

# Set the x-axis to log scale
ax1.set_xscale('log')

# Set labels for the axes
ax1.legend()
ax1.set_xlabel('Muon Energy [GeV]')
ax1.set_ylabel('Counts', color='black')
plt.xticks(nu_ticks)
#ax1.set_ylim(0, 0.3)

plt.show()

# %%
bin_centers
# Out:
# array([2.05352503e+01, 8.65964323e+01, 3.65174127e+02, 1.53992653e+03,
#        6.49381632e+03, 2.73841963e+04, 1.15478198e+05, 4.86967525e+05])

# %%
E_mu_bin_centers
# Out:
# array([2.05352503e+01, 8.65964323e+01, 3.65174127e+02, 1.53992653e+03,
#        6.49381632e+03, 2.73841963e+04, 1.15478198e+05, 4.86967525e+05])
